# %% [markdown]
# ### Homework

# %%
import pandas as pd
import numpy as np

interesting_columns = [
    'latitude',
    'longitude',
    'housing_median_age',
    'total_rooms',
    'total_bedrooms',
    'population',
    'households',
    'median_income',
    'median_house_value',
    'ocean_proximity',
]

df = pd.read_csv('housing.csv')
df = df[interesting_columns].fillna(0)
df['rooms_per_household'] = df.total_rooms/df.households
df['bedrooms_per_room'] = df.total_bedrooms/df.total_rooms
df['population_per_household'] = df.population/df.households
df.head().T
# Out:
#                                  0         1         2         3         4
# latitude                     37.88     37.86     37.85     37.85     37.85
# longitude                  -122.23   -122.22   -122.24   -122.25   -122.25
# housing_median_age            41.0      21.0      52.0      52.0      52.0
# total_rooms                  880.0    7099.0    1467.0    1274.0    1627.0
# total_bedrooms               129.0    1106.0     190.0     235.0     280.0
# population                   322.0    2401.0     496.0     558.0     565.0
# households                   126.0    1138.0     177.0     219.0     259.0
# median_income               8.3252    8.3014    7.2574    5.6431    3.8462
# median_house_value        452600.0  358500.0  352100.0  341300.0  342200.0
# ocean_proximity           NEAR BAY  NEAR BAY  NEAR BAY  NEAR BAY  NEAR BAY
# rooms_per_household       6.984127  6.238137  8.288136  5.817352  6.281853
# bedrooms_per_room         0.146591  0.155797  0.129516  0.184458  0.172096
# population_per_household  2.555556  2.109842   2.80226  2.547945  2.181467

# %% [markdown]
# #### Q1: What is the most frequent observation (mode) for the column ocean_proximity?

# %%
df.ocean_proximity.mode()
# Out:
# 0    <1H OCEAN
# Name: ocean_proximity, dtype: object

# %% [markdown]
# #### Q2: Create the correlation matrix and find the two features with the biggest correlation?

# %%
from IPython.display import display
numerical = df.columns[df.dtypes != 'object'].to_list()
corr_M = pd.DataFrame(index=numerical, columns=numerical)
for column_a in numerical:
    for column_b in numerical:
        corr_M.loc[column_a, column_b] = df[column_a].corr(df[column_b])
        


display(corr_M)
# Out:
#                           latitude longitude housing_median_age total_rooms  \
# latitude                       1.0 -0.924664           0.011173     -0.0361
# longitude                -0.924664       1.0          -0.108197    0.044568
# housing_median_age        0.011173 -0.108197                1.0   -0.361262
# total_rooms                -0.0361  0.044568          -0.361262         1.0
# total_bedrooms           -0.065318  0.068082          -0.317063    0.920196
# population               -0.108785  0.099773          -0.296244    0.857126
# households               -0.071035   0.05531          -0.302916    0.918484
# median_income            -0.079809 -0.015176          -0.119034     0.19805
# median_house_value        -0.14416 -0.045967           0.105623    0.134153
# rooms_per_household       0.106389  -0.02754          -0.153277    0.133798
# bedrooms_per_room        -0.104112  0.084836           0.125396   -0.174583
# population_per_household  0.002366  0.002476           0.013191   -0.024581
#
#                          total_bedrooms population households median_income  \
# latitude                      -0.065318  -0.108785  -0.071035     -0.079809
# longitude                      0.068082   0.099773    0.05531     -0.015176
# housing_median_age            -0.317063  -0.296244  -0.302916     -0.119034
# total_rooms                    0.920196   0.857126   0.918484       0.19805
# total_bedrooms                      1.0   0.866266   0.966507     -0.007295
# population                     0.866266        1.0   0.907222      0.004834
# households                     0.966507   0.907222        1.0      0.013033
# median_income                 -0.007295   0.004834   0.013033           1.0
# median_house_value             0.049148   -0.02465   0.065843      0.688075
# rooms_per_household            0.002717  -0.072213  -0.080598      0.326895
# bedrooms_per_room              0.122205   0.031397   0.059818     -0.573836
# population_per_household      -0.028019   0.069863  -0.027309      0.018766
#
#                          median_house_value rooms_per_household  \
# latitude                           -0.14416            0.106389
# longitude                         -0.045967            -0.02754
# housing_median_age                 0.105623           -0.153277
# total_rooms                        0.134153            0.133798
# total_bedrooms                     0.049148            0.002717
# population                         -0.02465           -0.072213
# households                         0.065843           -0.080598
# median_income                      0.688075            0.326895
# median_house_value                      1.0            0.151948
# rooms_per_household                0.151948                 1.0
# bedrooms_per_room                 -0.238759           -0.387465
# population_per_household          -0.023737           -0.004852
#
#                          bedrooms_per_room population_per_household
# latitude                         -0.104112                 0.002366
# longitude                         0.084836                 0.002476
# housing_median_age                0.125396                 0.013191
# total_rooms                      -0.174583                -0.024581
# total_bedrooms                    0.122205                -0.028019
# population                        0.031397                 0.069863
# households                        0.059818                -0.027309
# median_income                    -0.573836                 0.018766
# median_house_value               -0.238759                -0.023737
# rooms_per_household              -0.387465                -0.004852
# bedrooms_per_room                      1.0                 0.003047
# population_per_household          0.003047                      1.0

# %%
max_correlation = 0
correlated_ones = None
for i in range(len(numerical)):
    for j in range(i+1, len(numerical)):
        if corr_M.loc[numerical[i], numerical[j]] > max_correlation:
            max_correlation = corr_M.loc[numerical[i], numerical[j]]
            correlated_ones = (numerical[i], numerical[j])
print(max_correlation, correlated_ones)
# Out:
# 0.966507240042039 ('total_bedrooms', 'households')

# %% [markdown]
# #### Make median_house_value binary

# %%
m = df.median_house_value.mean()
df['above_average'] = (df['median_house_value'] > m).astype(int)

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

df_full_train, df_test = train_test_split(df, test_size=0.2)

df_train, df_val = train_test_split(df_full_train, test_size=0.25)

y_test = df_test.above_average.to_numpy()
yp_test = df_test.median_house_value.to_numpy()
del df_test['above_average']
del df_test['median_house_value']

y_val = df_val.above_average.to_numpy()
yp_val = df_val.median_house_value.to_numpy()
del df_val['above_average']
del df_val['median_house_value']

y_train = df_train.above_average.to_numpy()
yp_train = df_train.median_house_value.to_numpy()
del df_train['above_average']
del df_train['median_house_value']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lecc/Documents/MEGA/to study/Machine Learning/ML Zoom Camp/ml-zoomcamp2022/03 - Classification/homework.ipynb Cell 10 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/lecc/Documents/MEGA/to%20study/Machine%20Learning/ML%20Zoom%20Camp/ml-zoomcamp2022/03%20-%20Classification/homework.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a> del df_test['median_house_value']
#      <a href='vscode-notebook-cell:/Users/lecc/Documents/MEGA/to%20study/Machine%20Learning/ML%20Zoom%20Camp/ml-zoomcamp2022/03%20-%20Classification/homework.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a> y_val = df_val.above_average.to_numpy()
# ---> <a href='vscode-notebook-cell:/Users/lecc/Documents/MEGA/to%20study/Machine%20Learning/ML%20Zoom%20Camp/ml-zoomcamp2022/03%20-%20Classification/homework.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a> yp_val = df_test.median_house_value.to_numpy()
#      <a href='vscode-notebook-cell:/Users/lecc/Documents/MEGA/to%20study/Machine%20Learning/ML%20Zoom%20Camp/ml-zoomcamp2022/03%20-%20Classification/homework.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> del df_val['above_average']
#      <a href='vscode-notebook-cell:/Users/lecc/Documents/MEGA/to%20study/Machine%20Learning/ML%20Zoom%20Camp/ml-zoomcamp2022/03%20-%20Classification/homework.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> del df_val['median_house_value']
#
# File ~/opt/miniconda3/envs/ml-zoomcamp/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'median_house_value'

# %% [markdown]
# #### Q3: Mutual information

# %%
from sklearn.metrics import mutual_info_score
mi_score = mutual_info_score(df['ocean_proximity'], df['above_average'])
np.round(mi_score, decimals=2)

# %% [markdown]
# #### Q4: Train logistic regression

# %%
df.ocean_proximity.unique()

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)

train_dict = df_train.to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_val)
global_accuracy = (y_pred == y_val).mean()
np.round(global_accuracy, decimals=2)

# %% [markdown]
# #### Q5: find the least useful feature using the feature elimination technique.

# %%
q5_columns = ['total_rooms', 'total_bedrooms', 'population', 'households']


dv = DictVectorizer(sparse=False)

train_dict = df_train[q5_columns].to_dict(orient='records')
_X_train = dv.fit_transform(train_dict)

val_dict = df_val[q5_columns].to_dict(orient='records')
_X_val = dv.transform(val_dict)

model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
model.fit(_X_train, y_train)

y_pred = model.predict(_X_val)
_accuracy = (y_pred == y_val).mean()


less_important_feature = None
best_diff = 1
for column in q5_columns:
    dv = DictVectorizer(sparse=False)

    train_dict = df_train[q5_columns].drop(labels=column, axis=1).to_dict(orient='records')
    _X_train = dv.fit_transform(train_dict)

    val_dict = df_val[q5_columns].drop(labels=column, axis=1).to_dict(orient='records')
    _X_val = dv.transform(val_dict)

    model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)
    model.fit(_X_train, y_train)

    y_pred = model.predict(_X_val)
    current_accuracy = (y_pred == y_val).mean()
    if np.abs(current_accuracy-_accuracy) < best_diff:
        best_diff = np.abs(current_accuracy-_accuracy)
        less_important_feature = column
display(less_important_feature, best_diff)

# %% [markdown]
# #### Q6: Linear regression

# %%
df.head().T

# %%
from sklearn.linear_model import Ridge

y_log = np.log1p(yp_train)

def rmse(y_pred, y_ref):
    error = y_pred - y_ref
    mse = error**2
    return np.sqrt(mse.mean())

for a in [0, 0.01, 0.1, 1, 10]:
    model = Ridge(alpha=a, solver="sag", random_state=42)
    

    dv = DictVectorizer(sparse=False)

    train_dict = df_train.to_dict(orient='records')
    X_train = dv.fit_transform(train_dict)

    val_dict = df_val.to_dict(orient='records')
    X_val = dv.transform(val_dict)

    model.fit(X_train, yp_train)
    yp_pred = model.predict(X_val)
    print(a, rmse(yp_pred, yp_val))
